# %%
import json
import pandas as pd
import requests

# %%
# Get database from API

response = requests.get("http://127.0.0.1:8000/api/re-post2-list-create/")

# %%
# Get database from API's response

json_receive = response.json()
json_receive
# Out:
# [{'id': 20749538,
#   'created_at': '07-11-2022 22:42:18',
#   'title': 'Độc quyền! Qũy lô biệt thự giá rẻ khu đô thị Vạn Xuân - Langbiang Town Lạc Dương - 0904668***',
#   'address': 'Dự án Langbiang Town Đà Lạt, Đường Tỉnh Lộ 79, Thị trấn Lạc Dương, Lạc Dương, Lâm Đồng',
# ...

# %%
# Get needed data from json_receive
id_post = []
region = []
area = []
price = []
mat_tien = []
huong_nha = []
duong_vao = []
bedroom_number = []
toilet_number = []
phap_ly = []

for post in json_receive:
    id_post = []
